# %%
branch = !!!branch!!!
git_user = !!!git_user!!!
git_repo = !!!git_repo!!!
wandb_flag = !!!wandb_flag!!!

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_git = user_secrets.get_secret("git_token")
secret_wandb = user_secrets.get_secret("wandb_api_key")

# %% [markdown]
# # Setup weights and biases

# %%
if wandb_flag:
    # !pip install wandb >/dev/null
    # !wandb login secret_wandb

# %% [markdown]
# # Clone git repo

# %%
# %cd ~
# !git clone https://oauth2:$secret_git@github.com/$git_user/$git_repo >/dev/null
# %cd $git_repo
# !git checkout $branch
# !pip install torch_geometric

# %% [markdown]
# # Launch training

# %%
wb_ext = "-nowb" if not wandb_flag else ""
# !python local_train.py $wb_ext
